# %%
import importlib
import RefactoredPreProcess
_=importlib.reload(RefactoredPreProcess)

# %%
raw3DdatabasePath = r"C:\Users\fhabi\Desktop\DataSet\3D_raw_Dataset"
MNItemplateMRIimagePath=r"C:\Users\fhabi\Desktop\DataSet\3D_raw_Dataset\MNI\MNI152_T1_2mm.nii"
registered3DdatasetPath=r"C:\Users\fhabi\Desktop\DataSet\3D_nii_Dataset_Registered"
raw2DatasetPath=r"C:\Users\fhabi\Desktop\DataSet\2D_nii_raw_Dataset"
Filtered2DatasetPath=r"C:\Users\fhabi\Desktop\DataSet\2D_nii_Filtered_Dataset"
datasetExplorer=PreProcess.DatasetExplorer(raw3DdatabasePath,"3D") #2D_skip
subjects=datasetExplorer.GetSubjects()
datasetExplorer.FindAllFileTypes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4 raw2DatasetPath=r"C:\Users\fhabi\Desktop\DataSet\2D_nii_raw_Dataset"
#       5 Filtered2DatasetPath=r"C:\Users\fhabi\Desktop\DataSet\2D_nii_Filtered_Dataset"
# ----> 6 datasetExplorer=PreProcess.DatasetExplorer(raw3DdatabasePath,"3D") #2D_skip
#       7 subjects=datasetExplorer.GetSubjects()
#       8 datasetExplorer.FindAllFileTypes()
#
# NameError: name 'PreProcess' is not defined
